# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('./letters_CG.txt', sep='\s+', engine='python', header=0)
df.rename(columns={'#a':'a'}, inplace=True)
df.head()
# Out:
#   Class  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0     C      4     10      5     8      2      5      7      7     10      7
# 1     C      3      5      4     4      2      4      8      5      7     12
# 2     G      5     10      6     7      3      8      7      8      8      6
# 3     C      5      9      6     7      4      3      8      6      7     12
# 4     G      4      8      5     6      3      6      6      7      6     10
#
#    x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0      6     13      1      8      4      9
# 1      9     11      1     10      2      7
# 2      7      9      2      7      5     10
# 3     10     13      1      9      3      7
# 4      7     12      2      9      4      9

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(my_data[['width','high']])
y_predicted
my_data['cluster']=y_predicted
my_data.head()

# %%
plt.scatter(my_data.width,df['high'])
plt.xlabel('width')
plt.ylabel('high')

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['width','high']])
y_predicted
df['cluster']=y_predicted
df.head()

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.width,df1['high'],color='green')
plt.scatter(df2.width,df2['high'],color='red')
plt.scatter(df3.width,df3['high'],color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('high')
plt.ylabel('width')
plt.legend()

# %%
scaler = MinMaxScaler()

scaler.fit(df[['width']])
df['width'] = scaler.transform(df[['width']])

scaler.fit(df[['high']])
df['high'] = scaler.transform(df[['high']])
df.head()

plt.scatter(df.high,df['width'])

km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['high','width']])
y_predicted

df['cluster']=y_predicted
df.head()
